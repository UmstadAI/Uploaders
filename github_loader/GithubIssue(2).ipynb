# %%
import os
import json

import pandas as pd
import numpy as np
import openai

df = pd.read_csv('output.csv')

# %%
df = df[df['comments'].apply(lambda x: len(x) > 3)]
df
# Out:
#      number                                              title        writer  \
# 0      1214                     Memory leak of 150MB per proof  mitschabaude
# 5      1207  Enable compiling smart contracts along with al...  mitschabaude
# 11     1189  Proof.fromJSON() for times in a process, faile...  coldstar1993
# 13     1185                          Expose dummyBase64Proof()       maht0rz
# 15     1174  Remove Poseidon from PLUME [ERC 7524 incompati...   Divide-By-0
# ..      ...                                                ...           ...
# 647      18       Ensure tree shaking is used during the build  jasongitmail
# 648      17                    Convert the build to output ES6  jasongitmail
# 649      16                    Get build to work on the client  jasongitmail
# 650      15             Change the build to output 4 artifacts  jasongitmail
# 651       1                                 Building Snarkette         idkjs
#
#     is_open                                               body  \
# 0      open  Reported on discord:\r\n![image](https://githu...
# 5      open  **Why**: Currently, `zk deploy` fails if the c...
# 11     open  I hv a zkProgram named `JoinSplitProver `and i...
# 13   closed  Would it be possible to expose `dummyBase64Pro...
# 15   closed  We noticed that you deviated from [ERC 7524](h...
# ..      ...                                                ...
# 647  closed  We need to get the client bundle size _much_ s...
# 648  closed  Todo: Check with Nathan & Martin to ask about ...
# 649  closed                                                NaN
# 650  closed  - prover.js\r\n- prover.key\r\n- verifier.js \...
# 651  closed  I would like to know how to build the dune dep...
#
#                                               comments
# 0    [('dfstio', "It was tested using the code in h...
# 5    [('dfstio', 'The better solution would be to e...
# 11   [('Comdex', 'This seems to be related to the w...
# 13   [('mitschabaude', 'No reason, PR welcome!'), (...
# 15   [('Trivo25', 'Thanks for raising this issue! W...
# ..                                                 ...
# 647  [('mitschabaude', 'I already poked into this a...
# 648  [('mitschabaude', "Initial progress: I tried t...
# 649  [('mitschabaude', "I'm not sure what this was ...
# 650  [('bkase', "Note the verifier.js/verifier.key ...
# 651  [('mitschabaude', "This is outdated - snarkyjs...
#
# [376 rows x 6 columns]

# %%
split_df = np.array_split(df, len(df))
split_df[7]
# Out:
# /Users/berkingurcan/opt/anaconda3/envs/py39/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
#     number                                   title writer is_open body  \
# 28    1148  Port LSL and LSR gadgets to TypeScript   nicc    open  NaN
#
#                              comments
# 28  [('Trivo25', 'depends on #1139')]

# %%
SUMMARIZE_PROMPT = '''You are a professional MINA zkApp Developer. 
    The data is about Github Issues and their comments. 
    Understand the issue correctly. If solution is in the comments column deduct the solution
    explain it in detail to junior MINA zkApp Developer who has this problem. 
    If solution is solved by Pull Request include the PR number as a solution.
    If solution includes external link, provide it to user as a solution.
    If solution is not clear or not found in comments, Try to produce some solution suggestions.
    So, show the solution as the format:
    Issue: issue body 
    Solution: 
    Cause of the problem and detailed solution and explanation of the problem'''

FULL_PROMPT = '''You are a professional MINA zkApp Developer. 
    The data is about Github Issues and their comments. 
    Understand the issue correctly. If solution is in the comments column deduct the solution. 
    Do not summarize the solution comment. We need all data, code examples etc. for the solution.
    If solution is solved by Pull Request include the PR number as a solution.
    If solution includes external link, provide it to user as a solution.
    If solution is not clear or not found in comments, Try to produce some solution suggestions.
    So, show the solution like:
        Issue: Issue body
        Solution: Cause of the problem and detailed solution and explanation of the problem
    '''

STORE_FORMAT = '''You are a professional MINA zkApp Developer. 
    The data is about Github Issues and their comments. 
    Understand the issue correctly. If solution is in the comments column deduct the solution. 
    Do not summarize the solution comment. We need all data, code examples etc. for the solution.
    If solution is solved by Pull Request include the PR number as a solution.
    If solution includes external link, provide it to user as a solution.
    If solution is not clear or not found in comments, Try to produce some solution suggestions.
    So, export as a json object the issue solution like:
    {issue: Issue body,
    solution: Cause of the problem and detailed solution and explanation of the problem} '''

# %%
## Tools
import json

from typing import Type
from pydantic import BaseModel, Field
from langchain.tools import BaseTool

class JsonExporterInput(BaseModel):
    issue: str = Field(description="issue body")
    solution: str = Field(description="solution content")

class JsonExporterTool(BaseTool):
    name = "export_json"
    description = """takes issue and solution and exports it as json"""
    
    args_schema: Type[BaseModel] = JsonExporterInput

    def _run(self, issue: str, solution: str):

        json_object = {
            "issue": issue,
            "solution": solution
        }
        print("heyo: ", json.dumps(json_object))
        output.append(json.dumps(json_object))
        return json.dumps(json_object)

# %%
from langchain_experimental.agents.agent_toolkits import create_pandas_dataframe_agent
from langchain.chat_models import ChatOpenAI
from langchain.agents.agent_types import AgentType

from langchain.llms import OpenAI

OPENAI_API_KEY = ''

def export_issue(index):
    llm = ChatOpenAI(temperature=0.1, openai_api_key=OPENAI_API_KEY, model="gpt-3.5-turbo-0613")
    llmz = OpenAI(temperature=0, openai_api_key=OPENAI_API_KEY )
    tools = [JsonExporterTool()]
    
    agent = create_pandas_dataframe_agent(
        llm,
        split_df[index], 
        verbose=True,
        agent_type=AgentType.OPENAI_FUNCTIONS,
        agent_executor_kwargs={'handle_parsing_errors': True}
    )
    
    output = agent.run(
        FULL_PROMPT,
    )

    return output

# %%
output = export_issue(7)
output
# Out:
# > Entering new AgentExecutor chain...
#
# Invoking: `python_repl_ast` with `{'query': "df['body'][28]"}`
# responded: To understand the issue correctly, we need to analyze the `body` and `comments` columns of the dataframe. If the solution is mentioned in the `comments` column, we will deduct the solution. If the solution is solved by a Pull Request, we will include the PR number as a solution. If the solution includes an external link, we will provide it to the user. If the solution is not clear or not found in the comments, we will try to produce some solution suggestions.
#
# Here is an example of how the solution will be presented:
#
# Issue: Issue body
# Solution: Cause of the problem and detailed solution and explanation of the problem
#
# Let's apply this logic to the given dataframe.
#
# nan
# Invoking: `python_repl_ast` with `{'query': "df['comments'][28]"}`
#
#
# [('Trivo25', 'depends on #1139')]Issue: NaN
# Solution: The solution for this issue is mentioned in the comments. The user "Trivo25" mentioned that the solution depends on issue #1139.
#
# > Finished chain.
# 'Issue: NaN\nSolution: The solution for this issue is mentioned in the comments. The user "Trivo25" mentioned that the solution depends on issue #1139.'

# %%
import re
import json

def extract_issue_solution(input_string):
    issue_pattern = r'Issue:(.*?)Solution:'
    solution_pattern = r'Solution:(.*?)$'

    issue_match = re.search(issue_pattern, input_string, re.DOTALL)
    solution_match = re.search(solution_pattern, input_string, re.DOTALL)

    if issue_match and solution_match:
        issue_text = issue_match.group(1).strip()
        solution_text = solution_match.group(1).strip()

        output_dict = {
            "issue": issue_text,
            "solution": solution_text
        }

        output_json = json.dumps(output_dict, indent=4)
        return output_json

    else:
        return None

output_json = extract_issue_solution(output)
print(output_json)
# Out:
# {
#     "issue": "NaN",
#     "solution": "The solution for this issue is mentioned in the comments. The user \"Trivo25\" mentioned that the solution depends on issue #1139."
# }
